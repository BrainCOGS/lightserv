# %% [markdown]
# # Extract_metadata
# In this notebook, we will look at how to extract image metadata from the Z=0 plane of raw light sheet microscope data.

# %%
import tifffile
from xml.etree import ElementTree as ET

# %%
# Example Z=0 raw file
# raw_file = '/jukebox/LightSheetTransfer/kelly/201908_cfos/190820_m61468_observ_20190628_1d3x_647_008na_1hfds_z5um_250msec_14-50-40/14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif' 
# raw_file = '/jukebox/LightSheetData/rat-brody/190523_test_BABB15_2Hr5DCM_4x_488_008na_1hfLs_z5um_100msec_14-15-46/14-15-46_UltraII_raw_RawDataStack_C00_xyz-Table Z0000.ome.tif'
# raw_file = '/jukebox/wang/seagravesk/lightsheet/cfos_raw_images/cfos/171206_f37077_observer_20171011_488_015na_1hfsds_z5um_150msec_13-45-20/13-45-20_UltraII_raw_DataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif'
raw_file = '/jukebox/LightSheetTransfer/kelly/201908_cfos/190820_m61468_observ_20190628_1d3x_647_008na_1hfds_z5um_250msec_14-50-40/14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif'

# %%
# Grab the metadata tags
with tifffile.TiffFile(raw_file) as tif:
    tags = tif.pages[0].tags
len(tags.keys())
# Out:
# 17

# %%
tags
# Out:
# {'ImageWidth': <tifffile.tifffile.TiffTag at 0x7fba54574318>,
#  'ImageLength': <tifffile.tifffile.TiffTag at 0x7fba545caae8>,
#  'BitsPerSample': <tifffile.tifffile.TiffTag at 0x7fba545dd9f8>,
#  'Compression': <tifffile.tifffile.TiffTag at 0x7fba545dd958>,
#  'PhotometricInterpretation': <tifffile.tifffile.TiffTag at 0x7fba545dd8b8>,
#  'DocumentName': <tifffile.tifffile.TiffTag at 0x7fba545dd098>,
#  'ImageDescription': <tifffile.tifffile.TiffTag at 0x7fba545743b8>,
#  'Make': <tifffile.tifffile.TiffTag at 0x7fba545744a8>,
#  'Model': <tifffile.tifffile.TiffTag at 0x7fba545744f8>,
#  'StripOffsets': <tifffile.tifffile.TiffTag at 0x7fba54574548>,
#  'Orientation': <tifffile.tifffile.TiffTag at 0x7fba54574598>,
#  'SamplesPerPixel': <tifffile.tifffile.TiffTag at 0x7fba545745e8>,
#  'RowsPerStrip': <tifffile.tifffile.TiffTag at 0x7fba54574638>,
#  'StripByteCounts': <tifffile.tifffile.TiffTag at 0x7fba54574688>,
#  'PlanarConfiguration': <tifffile.tifffile.TiffTag at 0x7fba545746d8>,
#  'DateTime': <tifffile.tifffile.TiffTag at 0x7fba54574728>,
#  'ImageDepth': <tifffile.tifffile.TiffTag at 0x7fba54574778>}

# %%
for key in tags.keys():
    print(tags[key])
# Out:
# TiffTag 256 ImageWidth 1H @11079926  2160
# TiffTag 257 ImageLength 1H @11079938  2560
# TiffTag 258 BitsPerSample 1H @11079950  16
# TiffTag 259 Compression 1H @11079962  NONE
# TiffTag 262 PhotometricInterpretation 1H @11079974  MINISBLACK
# TiffTag 269 DocumentName 1s @11079986
# TiffTag 270 ImageDescription 1075436s @11100636  <?xml version="1.0" encoding="
# TiffTag 271 Make 10s @11100606  ImSpector
# TiffTag 272 Model 4s @11080022  130
# TiffTag 273 StripOffsets 2560I @11090366  (8, 4328, 8648, 12968, 17288, 21608,
# TiffTag 274 Orientation 1H @11080046  TOPLEFT
# TiffTag 277 SamplesPerPixel 1H @11080058  1
# TiffTag 278 RowsPerStrip 1H @11080070  1
# TiffTag 279 StripByteCounts 2560I @11080126  (4320, 4320, 4320, 4320, 4320, 432
# TiffTag 284 PlanarConfiguration 1H @11080094  CONTIG
# TiffTag 306 DateTime 20s @11100616  2019-08-20 14:50:47
# TiffTag 32997 ImageDepth 1I @11080118  1

# %%
tags['DateTime'].value
# Out:
# '2019-08-20 14:50:47'

# %%
# To actually extract info use
tag = tags['ImageWidth']
print(tag.value)
# Out:
# 2160

# %% [markdown]
# ## Example: get the pixel size in x,y,z dimensions

# %%
# That info lives in a very long xml string stored in the 'ImageDescription' tag
xml_description=tags['ImageDescription'].value
# Print out first 1000 characters
xml_description[0:1000]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2008-02" xmlns:ca="http://www.openmicroscopy.org/Schemas/CA/2008-02" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2008-02 http://www.openmicroscopy.org/Schemas/OME/2008-02/ome.xsd" UUID="urn:uuid:C3F42E27-6499-429C-BDFF-115AC56D6CDD">\r\n<Experimenter ID="Experimenter:Zahra_Dhanerawala">\r\n<FirstName>Zahra</FirstName>\r\n<LastName>Dhanerawala</LastName>\r\n<Email>zmd@princeton.edu</Email>\r\n<Institution>PNI</Institution>\r\n</Experimenter>\r\n<Group ID="urn:lsid:imspector.group.id:Group:Wang_Lab" Name="Wang Lab"/>\r\n<Image ID="Image:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F" Name="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif" DefaultPixels="Pixels:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F">\r\n<CreationDate>2019-08-20T15:11:12</CreationDate>\r\n<Description>not_specified</Description>\r\n<Pixels ID="Pixels:282'

# %%
# Parse the xml using ElementTree
root = ET.fromstring(xml_description)
print(root)
# Out:
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}OME' at 0x7fba544f9408>

# %%
# The tree is graph-like so to access further down the tree loop through children of root node
for child in root:
    print(child.tag,child.attrib)
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Experimenter {'ID': 'Experimenter:Zahra_Dhanerawala'}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Group {'ID': 'urn:lsid:imspector.group.id:Group:Wang_Lab', 'Name': 'Wang Lab'}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Image {'ID': 'Image:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F', 'Name': '14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif', 'DefaultPixels': 'Pixels:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F'}
# {http://www.openmicroscopy.org/Schemas/CA/2008-02}CustomAttributes {}

# %%
# The "Image" tag, i.e. root[2] is the one we want to expand
for child in root[2]:
    print(child.tag,child.attrib)
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}CreationDate {}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Description {}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Pixels {'ID': 'Pixels:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F', 'DimensionOrder': 'XYCZT', 'PixelType': 'uint16', 'BigEndian': 'false', 'SizeX': '2160', 'SizeY': '2560', 'SizeZ': '1343', 'SizeT': '1', 'SizeC': '2', 'PhysicalSizeX': '5.000000', 'PhysicalSizeY': '5.000000', 'PhysicalSizeZ': '5.000000'}
# {http://www.openmicroscopy.org/Schemas/CA/2008-02}CustomAttributes {}

# %%
# The pixel size is in the PhysicalSizeX, PhysicalSizeY, PhysicalSizeZ attributes, which are in the "Pixels" tag
image_tag = root[2]
pixel_tag = image_tag[2]
pixel_dict = pixel_tag.attrib
pixel_dict
# print(pixel_dict['PhysicalSizeX'],pixel_dict['PhysicalSizeY'],pixel_dict['PhysicalSizeZ'])
# Out:
# {'ID': 'Pixels:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F',
#  'DimensionOrder': 'XYCZT',
#  'PixelType': 'uint16',
#  'BigEndian': 'false',
#  'SizeX': '2160',
#  'SizeY': '2560',
#  'SizeZ': '1343',
#  'SizeT': '1',
#  'SizeC': '2',
#  'PhysicalSizeX': '5.000000',
#  'PhysicalSizeY': '5.000000',
#  'PhysicalSizeZ': '5.000000'}

# %%
sizex=pixel_dict['PhysicalSizeX']

# %%
sizex
# Out:
# '5.000000'

# %%
s='5.00000'
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-c404e387b3f6> in <module>
#       1 s='5.00000'
# ----> 2 int(s)
#
# ValueError: invalid literal for int() with base 10: '5.00000'

# %%
# To get a better sense of what is stored in the xml description file, you can either save the xml as a file with 
# Extension .xml and then load it in a browser, or do:
import xml.dom.minidom
xmlstr = xml.dom.minidom.parseString(ET.tostring(root)).toprettyxml()
print(xmlstr)
# Out:
# <?xml version="1.0" ?>
# <ns0:OME UUID="urn:uuid:C3F42E27-6499-429C-BDFF-115AC56D6CDD" xmlns:ns0="http://www.openmicroscopy.org/Schemas/OME/2008-02" xmlns:ns2="http://www.openmicroscopy.org/Schemas/CA/2008-02" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2008-02 http://www.openmicroscopy.org/Schemas/OME/2008-02/ome.xsd">
#
#
# 	<ns0:Experimenter ID="Experimenter:Zahra_Dhanerawala">
#
#
# 		<ns0:FirstName>Zahra</ns0:FirstName>
#
#
# 		<ns0:LastName>Dhanerawala</ns0:LastName>
#
#
# 		<ns0:Email>zmd@princeton.edu</ns0:Email>
#
#
# 		<ns0:Institution>PNI</ns0:Institution>
#
#
# 	</ns0:Experimenter>
#
#
# 	<ns0:Group ID="urn:lsid:imspector.group.id:Group:Wang_Lab" Name="Wang Lab"/>
#
#
# 	<ns0:Image DefaultPixels="Pixels:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F" ID="Image:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F" Name="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif">
#
#
# 		<ns0:CreationDate>2019-08-20T15:11:12</ns0:CreationDate>
#
#
# 		<ns0:Description>not_specified</ns0:Description>
#
#
# 		<ns0:Pixels BigEndian="false" DimensionOrder="XYCZT" ID="Pixels:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F" PhysicalSizeX="5.000000" PhysicalSizeY="5.000000" PhysicalSizeZ="5.000000" PixelType="uint16" SizeC="2" SizeT="1" SizeX="2160" SizeY="2560" SizeZ="1343">
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="0">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif">urn:uuid:C3F42E27-6499-429C-BDFF-115AC56D6CDD</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="0">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0000_UltraII Filter0000.ome.tif">urn:uuid:C6B55485-A61C-4EB5-9EE3-F76ED24C8CC7</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="1">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0001_UltraII Filter0000.ome.tif">urn:uuid:D591F643-0215-473E-80F1-9408DB616CAD</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="1">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0001_UltraII Filter0000.ome.tif">urn:uuid:EABEFA70-A005-4D40-B211-1825FEB7DCD3</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="2">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0002_UltraII Filter0000.ome.tif">urn:uuid:70BDC03D-A354-4FFE-B352-82DD1CA096E9</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="2">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0002_UltraII Filter0000.ome.tif">urn:uuid:5CF4482F-74B9-44B4-B1EA-F1D566FC2BE3</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="3">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0003_UltraII Filter0000.ome.tif">urn:uuid:9CDAF283-2381-4DDA-A44C-FE7705D94807</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="3">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0003_UltraII Filter0000.ome.tif">urn:uuid:C3256864-2C47-4AD0-B83B-F9CC85722C7A</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="4">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0004_UltraII Filter0000.ome.tif">urn:uuid:7E4D53C5-AB6F-4564-8092-621E5D19BAED</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="4">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0004_UltraII Filter0000.ome.tif">urn:uuid:A9A64D89-EACF-4D83-81DA-981D2C22700F</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="5">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0005_UltraII Filter0000.ome.tif">urn:uuid:4BD36447-35BF-4A80-B60C-96581E7D9DB9</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="5">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0005_UltraII Filter0000.ome.tif">urn:uuid:72C580D3-5AA1-4682-9EC7-B7FADE7A3717</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="6">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0006_UltraII Filter0000.ome.tif">urn:uuid:AC3FB651-5D4D-4C10-9289-C70CB60BA692</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="6">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0006_UltraII Filter0000.ome.tif">urn:uuid:FA8EB743-1EBC-4F45-87DF-829EDD28AB82</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="7">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0007_UltraII Filter0000.ome.tif">urn:uuid:4863C483-3CBC-44F6-9A46-972E4B06340C</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="7">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0007_UltraII Filter0000.ome.tif">urn:uuid:BB51D26F-81E8-4325-B6B6-CE5D3BA7A308</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="8">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0008_UltraII Filter0000.ome.tif">urn:uuid:7E03C65E-2202-4C35-B398-45B6A8CFEA1E</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="8">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0008_UltraII Filter0000.ome.tif">urn:uuid:3EA20E73-4AB8-4A36-8629-1CBBD54B687C</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ
</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="88">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0088_UltraII Filter0000.ome.tif">urn:uuid:92602005-DE5C-467E-B220-E55B9D3842D6</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="88">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0088_UltraII Filter0000.ome.tif">urn:uuid:50EE478B-46DB-4DB5-9458-5C29CA2FC42C</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="0" FirstT="0" FirstZ="89">
#
#
# 				<ns0:UUID FileName="14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0089_UltraII Filter0000.ome.tif">urn:uuid:01137B5C-02E9-4F29-B49C-548DD401A2B2</ns0:UUID>
#
#
# 			</ns0:TiffData>
#
#
# 			<ns0:TiffData FirstC="1" FirstT="0" FirstZ="89">
#
#
# ...
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE14 Value="0" fname="UltraII dev14step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE14 Value="0" fname="UltraII dev14step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE14 Value="0" fname="UltraII dev14step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE14 Value="0" fname="UltraII dev14step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE14 Value="0" fname="UltraII dev14step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE14 Value="0" fname="UltraII dev14step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE14 Value="0" fname="UltraII dev14step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE14 Value="0" fname="UltraII dev14step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE14 Value="0" fname="UltraII dev14step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE13 Value="0" fname="UltraII dev13step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE12 Value="0" fname="UltraII dev12step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE11 Value="0" fname="UltraII dev11step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE10 Value="0" fname="UltraII dev10step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE9 Value="0" fname="UltraII dev9step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="0" fname="UltraII dev8step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="0" fname="UltraII dev8step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="0" fname="UltraII dev8step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="0" fname="UltraII dev8step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="0" fname="UltraII dev8step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="0" fname="UltraII dev8step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="0" fname="UltraII dev8step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="0" fname="UltraII dev8step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="400" fname="UltraII dev8step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE8 Value="200" fname="UltraII dev8step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="0" fname="UltraII dev7step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="0" fname="UltraII dev7step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="0" fname="UltraII dev7step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="0" fname="UltraII dev7step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="0" fname="UltraII dev7step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="7687" fname="UltraII dev7step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="0" fname="UltraII dev7step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="3599" fname="UltraII dev7step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="905" fname="UltraII dev7step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE7 Value="55" fname="UltraII dev7step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE6 Value="0" fname="UltraII dev6step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="0" fname="UltraII dev5step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="0" fname="UltraII dev5step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="0" fname="UltraII dev5step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="0" fname="UltraII dev5step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="0" fname="UltraII dev5step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="0" fname="UltraII dev5step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="0" fname="UltraII dev5step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="0" fname="UltraII dev5step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="897" fname="UltraII dev5step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE5 Value="47" fname="UltraII dev5step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE4 Value="0" fname="UltraII dev4step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE3 Value="0" fname="UltraII dev3step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="0" fname="UltraII dev2step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="0" fname="UltraII dev2step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="0" fname="UltraII dev2step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="0" fname="UltraII dev2step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="0" fname="UltraII dev2step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="0" fname="UltraII dev2step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="0" fname="UltraII dev2step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="0" fname="UltraII dev2step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="0" fname="UltraII dev2step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE2 Value="7000" fname="UltraII dev2step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="0" fname="UltraII dev1step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="0" fname="UltraII dev1step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="0" fname="UltraII dev1step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="0" fname="UltraII dev1step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="0" fname="UltraII dev1step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="0" fname="UltraII dev1step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="122" fname="UltraII dev1step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="0" fname="UltraII dev1step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="109" fname="UltraII dev1step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE1 Value="109" fname="UltraII dev1step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step9" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step8" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step7" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step6" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step5" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step4" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step3" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step2" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step1" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII_DeviceStepsUNDERSCORE0 Value="0" fname="UltraII dev0step0" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII__Filter_Motor_Number Value="9" fname="UltraII FilterMotorNumber" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII__Filter_Com_Port Value="3" fname="UltraII FilterComPort" nId="262148" nTy="2"/>
#
#
# 			<ns0:UltraII__Com_Port Value="2" fname="UltraII ComPort" nId="262148" nTy="2"/>
#
#
# 			<ns0:Measurement_Time Value="2019-08-20T13&amp;#58;54&amp;#58;07" fname="MeasTime" nId="524288" nTy="5"/>
#
#
# 		</ns0:PropArray>
#
#
# 	</ns2:CustomAttributes>
#
#
# </ns0:OME>

# %% [markdown]
# ## Example: get experimenter information (netid)

# %%
# The experimenter info is in the Experimenter tag:
exp_tag = root[0]
for child in exp_tag:
    print(child,child.attrib)
# Out:
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}FirstName' at 0x7fa448563188> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}LastName' at 0x7fa4485631d8> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}Email' at 0x7fa448563228> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}Institution' at 0x7fa448563278> {}

# %%
# Here we see the attrib dict is empty, so how do we actually extract the email?
email_tag = exp_tag[2]
print(dir(email_tag))
# Out:
# ['__class__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'attrib', 'clear', 'extend', 'find', 'findall', 'findtext', 'get', 'getchildren', 'getiterator', 'insert', 'items', 'iter', 'iterfind', 'itertext', 'keys', 'makeelement', 'remove', 'set', 'tag', 'tail', 'text']

# %%
email_tag.text
# Out:
# 'zmd@princeton.edu'

# %%
# But wait, it might just be that Zahra entered her information a long time ago in the GUI 
# and for every experiment her credentials show up. if this is the case, then this will not help us very much

# Here is a another dataset

# %% [markdown]
# ## Save the metadata xml file and view it in a browser (best option for viewing)

# %%
# Just need to write the xml string to a file
import os
output_filename = 'example_old_lightsheet_metadata.xml'
if not os.path.exists(output_filename):
    with open(output_filename,'w') as outfile:
        outfile.write(xml_description)
print("wrote %s" % output_filename)
# Out:
# wrote example_old_lightsheet_metadata.xml

# %% [markdown]
# ## Get the metadata from the customattributes child

# %%
for child in image_tag:
    print(child,child.attrib)
# Out:
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}CreationDate' at 0x7f19c6dc3458> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}Description' at 0x7f19c6dc34a8> {}
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}Pixels' at 0x7f19c6dc34f8> {'ID': 'Pixels:28212BB8-BEDE-4CD6-A6A9-8DAEA484C34F', 'DimensionOrder': 'XYCZT', 'PixelType': 'uint16', 'BigEndian': 'false', 'SizeX': '2160', 'SizeY': '2560', 'SizeZ': '1343', 'SizeT': '1', 'SizeC': '2', 'PhysicalSizeX': '5.000000', 'PhysicalSizeY': '5.000000', 'PhysicalSizeZ': '5.000000'}
# <Element '{http://www.openmicroscopy.org/Schemas/CA/2008-02}CustomAttributes' at 0x7f19c6e44c78> {}

# %%
custom_attributes_image = image_tag[-1]

# %%
custom_attributes_image[-7].attrib
# Out:
# {'ImspectorVersion': 'Imspector Pro 5.1.347'}

# %%
for child in custom_attributes:
    print(child.tag,child.attrib)
    print()
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Offset {'Offset_0': '5255.922852', 'Offset_1': '4600.228516', 'Offset_2': '0.0', 'Offset_3': '0.0'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Axis0 {'AxisName': 'xyz-Table Z', 'Offset': '-3355.000000', 'PhysicalUnit': '-5.000000', 'Steps': '1343'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Length {'Length_0': '10800.000000', 'Length_1': '12800.000000', 'Length_2': '1.000000', 'Length_3': '1.000000'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}AxesLabels {'X': 'UltraII X', 'Y': 'UltraII Y', 'FirstAxis': 'None', 'SecondAxis': 'NONE', 'X-Unit': '&#181;m', 'Y-Unit': '&#181;m', 'FirstAxis-Unit': '', 'SecondAxis-Unit': ''}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}dSel {'X0': '496', 'Y0': '1288', 'Z0': '0', 'T0': '0', 'X1': '977', 'Y1': '1898', 'Z1': '-1', 'T1': '-1'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}dStampJmp {'dStampJmp0': '0', 'dStampJmp1': '0', 'dStampJmp2': '0', 'dStampJmp3': '0'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}dStampRes {'dStampRes0': '0', 'dStampRes1': '0', 'dStampRes2': '0', 'dStampRes3': '0'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}sDeviceKey {'sDeviceKey': ''}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}dDisplayMode {'dDisplayMode': '0'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}dHideMode {'dHideMode': '0'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}dHideAxis {'dHideAxis': '3'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}ColorMap {'ColorMap': '1'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}InstrumentMode {'InstrumentMode': '1.3x'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}MeasurementMode {'MeasurementMode': '3D'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Rating {'Rating': '0'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}UseMetaDataGlobal {'UseMetaDataGlobal': '1'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}ImspectorVersion {'ImspectorVersion': 'Imspector Pro 5.1.347'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}ObjectiveID {'ObjectiveID': 'not_specified'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}ObjectiveNA {'ObjectiveNA': 'not_specified'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}ObjectiveMedium {'ObjectiveMedium': 'not_specified'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}IsPartOfMosaic {'IsPartOfMosaic': '1'}
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}TileConfiguration {'TileConfiguration': '2   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,0.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0000_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,0.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0001_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-5.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0001_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-5.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0002_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-10.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0002_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-10.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0003_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-15.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0003_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-15.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0004_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-20.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0004_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-20.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0005_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-25.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0005_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-25.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0006_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-30.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0006_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-30.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0007_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-35.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0007_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-35.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0008_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-40.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0008_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-40.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0009_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-45.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0009_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-45.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0010_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-50.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0010_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-50.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0011_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-55.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0011_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-55.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0012_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-60.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0012_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,1,-60.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0013_UltraII Filter0000.ome.tif;;(5255.922852, 4600.228516,0,-65.000000,0.000000)   14-50-40_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0013_UltraII Filte ...
#
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Timestamps {}

# %%
custom_attributes = root[-1]

# %%
len(custom_attributes)
# Out:
# 1

# %%
proparray=custom_attributes[0]

# %%
proparray
# Out:
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}PropArray' at 0x1094f81d8>

# %%
for child in proparray:
    if 'UltraII_Na_Value' in child.tag:
        print(child.tag)
        print(child.attrib['Value'])
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}UltraII_Na_Value
# <class 'str'>

# %%
# Channel 555 metadata:
Z0_path = '/jukebox/LightSheetData/lightserv_testing/ahoag/test/sample-001/test555/15-15-58_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0001.ome.tif'

# %%
# Grab the metadata tags
with tifffile.TiffFile(Z0_path) as tif:
    tags = tif.pages[0].tags
len(tags.keys())
# Out:
# 16

# %%
tags
# Out:
# {'ImageWidth': <tifffile.tifffile.TiffTag at 0x1137f0c78>,
#  'ImageLength': <tifffile.tifffile.TiffTag at 0x1137f0db8>,
#  'BitsPerSample': <tifffile.tifffile.TiffTag at 0x1137f0e08>,
#  'Compression': <tifffile.tifffile.TiffTag at 0x1137f0e58>,
#  'PhotometricInterpretation': <tifffile.tifffile.TiffTag at 0x1137f05e8>,
#  'DocumentName': <tifffile.tifffile.TiffTag at 0x1137f0ea8>,
#  'Make': <tifffile.tifffile.TiffTag at 0x1137f0ef8>,
#  'Model': <tifffile.tifffile.TiffTag at 0x1137f0f48>,
#  'StripOffsets': <tifffile.tifffile.TiffTag at 0x1137f0f98>,
#  'Orientation': <tifffile.tifffile.TiffTag at 0x1141e3048>,
#  'SamplesPerPixel': <tifffile.tifffile.TiffTag at 0x1141e3098>,
#  'RowsPerStrip': <tifffile.tifffile.TiffTag at 0x1141e30e8>,
#  'StripByteCounts': <tifffile.tifffile.TiffTag at 0x1141e3138>,
#  'PlanarConfiguration': <tifffile.tifffile.TiffTag at 0x1141e3188>,
#  'DateTime': <tifffile.tifffile.TiffTag at 0x1141e31d8>,
#  'ImageDepth': <tifffile.tifffile.TiffTag at 0x1141e3228>}

# %%
tags['ImageDepth'].value
# Out:
# 1

# %%
xml_description = tags['ImageDescription'].value
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-6caf05c6bab9> in <module>
# ----> 1 xml_description = tags['ImageDescription'].value
#
# KeyError: 'ImageDescription'

# %%
xml_description
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2008-02" xmlns:ca="http://www.openmicroscopy.org/Schemas/CA/2008-02" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2008-02 http://www.openmicroscopy.org/Schemas/OME/2008-02/ome.xsd" UUID="urn:uuid:EE70C66A-0C5E-4D89-9B3B-B1819A5699EC">\r\n<Experimenter ID="Experimenter:not_specified_not_specified">\r\n<FirstName>not_specified</FirstName>\r\n<LastName>not_specified</LastName>\r\n<Email>not_specified</Email>\r\n<Institution>not_specified</Institution>\r\n</Experimenter>\r\n<Group ID="urn:lsid:imspector.group.id:Group:not_specified" Name="not_specified"/>\r\n<Image ID="Image:BB06B1DE-FC6F-45DB-9D67-9E871034CAB1" Name="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif" DefaultPixels="Pixels:BB06B1DE-FC6F-45DB-9D67-9E871034CAB1">\r\n<CreationDate>2019-07-26T15:32:35</CreationDate>\r\n<Description>not_specified</Description>\r\n<Pixels ID="Pixels:BB06B1DE-FC6F-45DB-9D67-9E871034CAB1" DimensionOrder="XYCZT" PixelType="uint16" BigEndian="false" SizeX="2160" SizeY="2560" SizeZ="760" SizeT="2" SizeC="2" PhysicalSizeX="5.000000" PhysicalSizeY="5.000000" PhysicalSizeZ="10.000000" TimeIncrement="0.000000">\r\n<TiffData FirstC="0" FirstZ="0" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0000_UltraII Filter0000.ome.tif">urn:uuid:EE70C66A-0C5E-4D89-9B3B-B1819A5699EC</UUID>\r\n</TiffData>\r\n<TiffData FirstC="1" FirstZ="0" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0000_UltraII Filter0000.ome.tif">urn:uuid:DCFBB27A-7A38-4736-954B-78C6BD0D4429</UUID>\r\n</TiffData>\r\n<TiffData FirstC="0" FirstZ="1" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0001_UltraII Filter0000.ome.tif">urn:uuid:885A4D2B-CBED-486F-81D9-1FF89893159A</UUID>\r\n</TiffData>\r\n<TiffData FirstC="1" FirstZ="1" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0001_UltraII Filter0000.ome.tif">urn:uuid:B072556A-2C43-4063-854D-19F04E40CC17</UUID>\r\n</TiffData>\r\n<TiffData FirstC="0" FirstZ="2" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0002_UltraII Filter0000.ome.tif">urn:uuid:C082EA12-E653-4D95-96B1-93A719B36680</UUID>\r\n</TiffData>\r\n<TiffData FirstC="1" FirstZ="2" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0002_UltraII Filter0000.ome.tif">urn:uuid:14456408-2288-467A-8629-66133D6AD93D</UUID>\r\n</TiffData>\r\n<TiffData FirstC="0" FirstZ="3" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0003_UltraII Filter0000.ome.tif">urn:uuid:29770F74-185B-451B-BC2B-ADF3AD689211</UUID>\r\n</TiffData>\r\n<TiffData FirstC="1" FirstZ="3" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0003_UltraII Filter0000.ome.tif">urn:uuid:9B106042-9DB6-4441-A7C4-EEAE2BABBFD4</UUID>\r\n</TiffData>\r\n<TiffData FirstC="0" FirstZ="4" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0004_UltraII Filter0000.ome.tif">urn:uuid:B98160FD-3FFA-4CBF-8A50-CFA6E1B6F767</UUID>\r\n</TiffData>\r\n<TiffData FirstC="1" FirstZ="4" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0004_UltraII Filter0000.ome.tif">urn:uuid:98A13F7D-2C95-4305-8D78-8EDCF2E8BC21</UUID>\r\n</TiffData>\r\n<TiffData FirstC="0" FirstZ="5" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C00_xyz-Table Z0005_UltraII Filter0000.ome.tif">urn:uuid:F1F08759-2252-4373-946C-DA6BB1A58735</UUID>\r\n</TiffData>\r\n<TiffData FirstC="1" FirstZ="5" FirstT="0">\r\n<UUID FileName="15-15-58_UltraII_raw_RawDataStack[00 x 00]_C01_xyz-Table Z0005_UltraII Filter0000.ome.tif">urn:uuid:2E9E15B0-49F5-46C0-A998-0C98F91C3914</UUID>\r ...

# %%
# Parse the xml using ElementTree
root = ET.fromstring(xml_description)
print(root)
# Out:
# <Element '{http://www.openmicroscopy.org/Schemas/OME/2008-02}OME' at 0x111bd0f98>

# %%
for child in root:
    print(child.tag)
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Experimenter
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Group
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Image
# {http://www.openmicroscopy.org/Schemas/CA/2008-02}CustomAttributes

# %%
image = root[2]
for child in image:
    print(child.tag,child.attrib)
# Out:
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}CreationDate {}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Description {}
# {http://www.openmicroscopy.org/Schemas/OME/2008-02}Pixels {'ID': 'Pixels:BB06B1DE-FC6F-45DB-9D67-9E871034CAB1', 'DimensionOrder': 'XYCZT', 'PixelType': 'uint16', 'BigEndian': 'false', 'SizeX': '2160', 'SizeY': '2560', 'SizeZ': '760', 'SizeT': '2', 'SizeC': '2', 'PhysicalSizeX': '5.000000', 'PhysicalSizeY': '5.000000', 'PhysicalSizeZ': '10.000000', 'TimeIncrement': '0.000000'}
# {http://www.openmicroscopy.org/Schemas/CA/2008-02}CustomAttributes {}

# %%
# Write the xml string to a file
import os
output_filename = 'example_filter0000_metadata.xml'
if not os.path.exists(output_filename):
    with open(output_filename,'w') as outfile:
        outfile.write(xml_description)
print("wrote %s" % output_filename)
# Out:
# wrote example_filter0000_metadata.xml
